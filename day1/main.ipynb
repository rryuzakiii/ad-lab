# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.arange(1, 10, 0.1)

# %%
ys = np.cos(xs)

# %%
plt.plot(xs,ys)

# %%
name ="londa"
print("helllo",name)
# Out:
# helllo londa

# %%
[_ for _ in range(1,1000) if _ % 2 == 0]
